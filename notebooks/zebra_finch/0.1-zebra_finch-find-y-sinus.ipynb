# %%
# for automatic reloading
# %load_ext autoreload
# %autoreload 2

# %%
from birdbrain.atlas import atlas
from birdbrain.utils import um_to_vox
from birdbrain.visualization.plotting_2d import plot_2d_coordinates
import numpy as np
# Out:
# /mnt/cube/tsainbur/conda_envs/tpy3/lib/python3.6/site-packages/tqdm/autonotebook/__init__.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %% [markdown]
# To request the zebra finch password email johan.vanaudekerke@uantwerpen.be

# %%
password = None

# %%
dset_dir = '../../data/processed/zebra_finch/'

zebra_finch_atlas = atlas(
    species = 'zebra_finch',
    dset_dir = dset_dir,
    um_mult = 100,
    smoothing = [], #['Brain', 'Brainregions']
    password = password
)
# Out:
# Data already download
# Getting voxel data from .img files...
# Getting location for each nucleus/region from voxel data...
# ...
# Atlas created

# %%
np.shape((zebra_finch_atlas.voxel_data.loc['Atlas', 'voxels']))
# Out:
# (256, 256, 256)

# %%
np.shape(zebra_finch_atlas.voxel_data.loc['Brain', 'voxels'])
# Out:
# (256, 256, 256)

# %%
plot_2d_coordinates(zebra_finch_atlas, point_in_um= [0,0,0], regions_to_plot=['Nuclei'],brain_masked_image='Atlas');
# Out:
# {'medial-lateral': 0, 'anterior-posterior': 0, 'dorsal-ventral': 0}
